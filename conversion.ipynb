# %%
import numpy as np
import tensorflow as tf
import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt
from spark_env.env import Environment
import time
import pandas as pd

# %%
app_registry = {'spark-565152936b3f47bb9e137e8fe3f60f4f': {'exec_limit': 2, 0: {0: {'dependencies': [], 'status': 'COMPLETE', 'num_tasks': 2, 'num_finished_tasks': 2}}, 1: {4: {'dependencies': [3], 'status': 'COMPLETE', 'num_tasks': 4, 'num_finished_tasks': 4}, 3: {'dependencies': [1, 2], 'status': 'COMPLETE', 'num_tasks': 4, 'num_finished_tasks': 4}, 1: {'dependencies': [], 'status': 'COMPLETE', 'num_tasks': 2, 'num_finished_tasks': 2}, 2: {'dependencies': [], 'status': 'COMPLETE', 'num_tasks': 2, 'num_finished_tasks': 2}}, 2: {11: {'dependencies': [10], 'status': 'COMPLETE', 'num_tasks': 8, 'num_finished_tasks': 8}, 10: {'dependencies': [9, 7, 8], 'status': 'COMPLETE', 'num_tasks': 8, 'num_finished_tasks': 8}, 8: {'dependencies': [7], 'status': 'COMPLETE', 'num_tasks': 4, 'num_finished_tasks': 4}, 9: {'dependencies': [], 'status': 'COMPLETE', 'num_tasks': 2, 'num_finished_tasks': 2}, 5: {'dependencies': [], 'status': 'SKIPPED'}, 6: {'dependencies': [], 'status': 'SKIPPED'}, 7: {'dependencies': [], 'status': 'SKIPPED'}}, 3: {21: {'dependencies': [20], 'status': 'COMPLETE', 'num_tasks': 16, 'num_finished_tasks': 16}, 20: {'dependencies': [19, 17, 18], 'status': 'COMPLETE', 'num_tasks': 16, 'num_finished_tasks': 16}, 18: {'dependencies': [17], 'status': 'COMPLETE', 'num_tasks': 8, 'num_finished_tasks': 8}, 19: {'dependencies': [], 'status': 'COMPLETE', 'num_tasks': 2, 'num_finished_tasks': 2}, 15: {'dependencies': [], 'status': 'SKIPPED'}, 12: {'dependencies': [], 'status': 'SKIPPED'}, 16: {'dependencies': [], 'status': 'SKIPPED'}, 13: {'dependencies': [], 'status': 'SKIPPED'}, 17: {'dependencies': [], 'status': 'SKIPPED'}, 14: {'dependencies': [], 'status': 'SKIPPED'}}, 4: {34: {'dependencies': [33], 'status': 'COMPLETE', 'num_tasks': 32, 'num_finished_tasks': 32}, 33: {'dependencies': [30, 31, 32], 'status': 'COMPLETE', 'num_tasks': 32, 'num_finished_tasks': 32}, 31: {'dependencies': [], 'status': 'COMPLETE', 'num_tasks': 2, 'num_finished_tasks': 2}, 32: {'dependencies': [30], 'status': 'COMPLETE', 'num_tasks': 16, 'num_finished_tasks': 16}, 30: {'dependencies': [], 'status': 'SKIPPED'}, 27: {'dependencies': [], 'status': 'SKIPPED'}, 24: {'dependencies': [], 'status': 'SKIPPED'}, 28: {'dependencies': [], 'status': 'SKIPPED'}, 25: {'dependencies': [], 'status': 'SKIPPED'}, 22: {'dependencies': [], 'status': 'SKIPPED'}, 29: {'dependencies': [], 'status': 'SKIPPED'}, 26: {'dependencies': [], 'status': 'SKIPPED'}, 23: {'dependencies': [], 'status': 'SKIPPED'}}, 5: {50: {'dependencies': [49], 'status': 'COMPLETE', 'num_tasks': 64, 'num_finished_tasks': 64}, 49: {'dependencies': [48, 46, 47], 'status': 'COMPLETE', 'num_tasks': 64, 'num_finished_tasks': 64}, 47: {'dependencies': [46], 'status': 'COMPLETE', 'num_tasks': 32, 'num_finished_tasks': 32}, 48: {'dependencies': [], 'status': 'COMPLETE', 'num_tasks': 2, 'num_finished_tasks': 2}, 45: {'dependencies': [], 'status': 'SKIPPED'}, 37: {'dependencies': [], 'status': 'SKIPPED'}, 46: {'dependencies': [], 'status': 'SKIPPED'}, 38: {'dependencies': [], 'status': 'SKIPPED'}, 39: {'dependencies': [], 'status': 'SKIPPED'}, 40: {'dependencies': [], 'status': 'SKIPPED'}, 41: {'dependencies': [], 'status': 'SKIPPED'}, 35: {'dependencies': [], 'status': 'SKIPPED'}, 42: {'dependencies': [], 'status': 'SKIPPED'}, 36: {'dependencies': [], 'status': 'SKIPPED'}, 43: {'dependencies': [], 'status': 'SKIPPED'}, 44: {'dependencies': [], 'status': 'SKIPPED'}}, 6: {69: {'dependencies': [68], 'status': 'COMPLETE', 'num_tasks': 128, 'num_finished_tasks': 128}, 68: {'dependencies': [66, 67, 65], 'status': 'COMPLETE', 'num_tasks': 128, 'num_finished_tasks': 128}, 66: {'dependencies': [], 'status': 'COMPLETE', 'num_tasks': 2, 'num_finished_tasks': 2}, 67: {'dependencies': [65], 'status': 'COMPLETE', 'num_tasks': 64, 'num_finished_tasks': 64}, 51: {'dependencies': [], 'status': 'SKIPPED'}, 60: {'dependencies': [], 'status': 'SKIPPED'}, 52: {'dependencies': [], 'status': 'SKIPPED'}, 53: {'dependencies': [], 'status': 'SKIPPED'}, 54: {'dependencies': [], 'status': 'SKIPPED'}, 61: {'dependencies': [], 'status': 'SKIPPED'}, 55: {'dependencies': [], 'status': 'SKIPPED'}, 62: {'dependencies': [], 'status': 'SKIPPED'}, 63: {'dependencies': [], 'status': 'SKIPPED'}, 64: {'dependencies': [], 'status': 'SKIPPED'}, 56: {'dependencies': [], 'status': 'SKIPPED'}, 57: {'dependencies': [], 'status': 'SKIPPED'}, 58: {'dependencies': [], 'status': 'SKIPPED'}, 65: {'dependencies': [], 'status': 'SKIPPED'}, 59: {'dependencies': [], 'status': 'SKIPPED'}}, 7: {91: {'dependencies': [90], 'status': 'COMPLETE', 'num_tasks': 256, 'num_finished_tasks': 256}, 90: {'dependencies': [88, 89, 87], 'status': 'COMPLETE', 'num_tasks': 256, 'num_finished_tasks': 256}, 88: {'dependencies': [], 'status': 'COMPLETE', 'num_tasks': 2, 'num_finished_tasks': 2}, 89: {'dependencies': [87], 'status': 'COMPLETE', 'num_tasks': 128, 'num_finished_tasks': 128}, 81: {'dependencies': [], 'status': 'SKIPPED'}, 82: {'dependencies': [], 'status': 'SKIPPED'}, 74: {'dependencies': [], 'status': 'SKIPPED'}, 83: {'dependencies': [], 'status': 'SKIPPED'}, 75: {'dependencies': [], 'status': 'SKIPPED'}, 76: {'dependencies': [], 'status': 'SKIPPED'}, 77: {'dependencies': [], 'status': 'SKIPPED'}, 84: {'dependencies': [], 'status': 'SKIPPED'}, 78: {'dependencies': [], 'status': 'SKIPPED'}, 70: {'dependencies': [], 'status': 'SKIPPED'}, 85: {'dependencies': [], 'status': 'SKIPPED'}, 71: {'dependencies': [], 'status': 'SKIPPED'}, 86: {'dependencies': [], 'status': 'SKIPPED'}, 72: {'dependencies': [], 'status': 'SKIPPED'}, 87: {'dependencies': [], 'status': 'SKIPPED'}, 79: {'dependencies': [], 'status': 'SKIPPED'}, 73: {'dependencies': [], 'status': 'SKIPPED'}, 80: {'dependencies': [], 'status': 'SKIPPED'}}, 8: {116: {'dependencies': [115], 'status': 'COMPLETE', 'num_tasks': 512, 'num_finished_tasks': 512}, 115: {'dependencies': [114, 112, 113], 'status': 'COMPLETE', 'num_tasks': 512, 'num_finished_tasks': 512}, 113: {'dependencies': [112], 'status': 'COMPLETE', 'num_tasks': 256, 'num_finished_tasks': 256}, 114: {'dependencies': [], 'status': 'COMPLETE', 'num_tasks': 2, 'num_finished_tasks': 2}, 102: {'dependencies': [], 'status': 'SKIPPED'}, 96: {'dependencies': [], 'status': 'SKIPPED'}, 103: {'dependencies': [], 'status': 'SKIPPED'}, 104: {'dependencies': [], 'status': 'SKIPPED'}, 111: {'dependencies': [], 'status': 'SKIPPED'}, 105: {'dependencies': [], 'status': 'SKIPPED'}, 97: {'dependencies': [], 'status': 'SKIPPED'}, 112: {'dependencies': [], 'status': 'SKIPPED'}, 106: {'dependencies': [], 'status': 'SKIPPED'}, 98: {'dependencies': [], 'status': 'SKIPPED'}, 92: {'dependencies': [], 'status': 'SKIPPED'}, 99: {'dependencies': [], 'status': 'SKIPPED'}, 100: {'dependencies': [], 'status': 'SKIPPED'}, 107: {'dependencies': [], 'status': 'SKIPPED'}, 101: {'dependencies': [], 'status': 'SKIPPED'}, 93: {'dependencies': [], 'status': 'SKIPPED'}, 108: {'dependencies': [], 'status': 'SKIPPED'}, 94: {'dependencies': [], 'status': 'SKIPPED'}, 109: {'dependencies': [], 'status': 'SKIPPED'}, 95: {'dependencies': [], 'status': 'SKIPPED'}, 110: {'dependencies': [], 'status': 'SKIPPED'}}, 9: {144: {'dependencies': [143], 'status': 'COMPLETE', 'num_tasks': 1024, 'num_finished_tasks': 1024}, 143: {'dependencies': [140, 141, 142], 'status': 'COMPLETE', 'num_tasks': 1024, 'num_finished_tasks': 1024}, 141: {'dependencies': [], 'status': 'COMPLETE', 'num_tasks': 2, 'num_finished_tasks': 2}, 142: {'dependencies': [140], 'status': 'COMPLETE', 'num_tasks': 512, 'num_finished_tasks': 512}, 132: {'dependencies': [], 'status': 'SKIPPED'}, 133: {'dependencies': [], 'status': 'SKIPPED'}, 125: {'dependencies': [], 'status': 'SKIPPED'}, 126: {'dependencies': [], 'status': 'SKIPPED'}, 127: {'dependencies': [], 'status': 'SKIPPED'}, 128: {'dependencies': [], 'status': 'SKIPPED'}, 129: {'dependencies': [], 'status': 'SKIPPED'}, 121: {'dependencies': [], 'status': 'SKIPPED'}, 122: {'dependencies': [], 'status': 'SKIPPED'}, 123: {'dependencies': [], 'status': 'SKIPPED'}, 124: {'dependencies': [], 'status': 'SKIPPED'}, 117: {'dependencies': [], 'status': 'SKIPPED'}, 139: {'dependencies': [], 'status': 'SKIPPED'}, 118: {'dependencies': [], 'status': 'SKIPPED'}, 140: {'dependencies': [], 'status': 'SKIPPED'}, 119: {'dependencies': [], 'status': 'SKIPPED'}, 120: {'dependencies': [], 'status': 'SKIPPED'}, 134: {'dependencies': [], 'status': 'SKIPPED'}, 135: {'dependencies': [], 'status': 'SKIPPED'}, 136: {'dependencies': [], 'status': 'SKIPPED'}, 137: {'dependencies': [], 'status': 'SKIPPED'}, 138: {'dependencies': [], 'status': 'SKIPPED'}, 130: {'dependencies': [], 'status': 'SKIPPED'}, 131: {'dependencies': [], 'status': 'SKIPPED'}}, 10: {175: {'dependencies': [174], 'status': 'COMPLETE', 'num_tasks': 2048, 'num_finished_tasks': 2048}, 174: {'dependencies': [171, 172, 173], 'status': 'COMPLETE', 'num_tasks': 2048, 'num_finished_tasks': 2048}, 172: {'dependencies': [], 'status': 'COMPLETE', 'num_tasks': 2, 'num_finished_tasks': 2}, 173: {'dependencies': [171], 'status': 'COMPLETE', 'num_tasks': 1024, 'num_finished_tasks': 1024}, 161: {'dependencies': [], 'status': 'SKIPPED'}, 153: {'dependencies': [], 'status': 'SKIPPED'}, 154: {'dependencies': [], 'status': 'SKIPPED'}, 155: {'dependencies': [], 'status': 'SKIPPED'}, 156: {'dependencies': [], 'status': 'SKIPPED'}, 148: {'dependencies': [], 'status': 'SKIPPED'}, 149: {'dependencies': [], 'status': 'SKIPPED'}, 171: {'dependencies': [], 'status': 'SKIPPED'}, 150: {'dependencies': [], 'status': 'SKIPPED'}, 151: {'dependencies': [], 'status': 'SKIPPED'}, 152: {'dependencies': [], 'status': 'SKIPPED'}, 145: {'dependencies': [], 'status': 'SKIPPED'}, 167: {'dependencies': [], 'status': 'SKIPPED'}, 146: {'dependencies': [], 'status': 'SKIPPED'}, 168: {'dependencies': [], 'status': 'SKIPPED'}, 147: {'dependencies': [], 'status': 'SKIPPED'}, 169: {'dependencies': [], 'status': 'SKIPPED'}, 170: {'dependencies': [], 'status': 'SKIPPED'}, 162: {'dependencies': [], 'status': 'SKIPPED'}, 163: {'dependencies': [], 'status': 'SKIPPED'}, 164: {'dependencies': [], 'status': 'SKIPPED'}, 165: {'dependencies': [], 'status': 'SKIPPED'}, 157: {'dependencies': [], 'status': 'SKIPPED'}, 166: {'dependencies': [], 'status': 'SKIPPED'}, 158: {'dependencies': [], 'status': 'SKIPPED'}, 159: {'dependencies': [], 'status': 'SKIPPED'}, 160: {'dependencies': [], 'status': 'SKIPPED'}}, 11: {209: {'dependencies': [208], 'status': 'COMPLETE', 'num_tasks': 4096, 'num_finished_tasks': 4096}, 208: {'dependencies': [205, 206, 207], 'status': 'COMPLETE', 'num_tasks': 4096, 'num_finished_tasks': 4096}, 206: {'dependencies': [205], 'status': 'COMPLETE', 'num_tasks': 2048, 'num_finished_tasks': 2048}, 207: {'dependencies': [], 'status': 'COMPLETE', 'num_tasks': 2, 'num_finished_tasks': 2}, 204: {'dependencies': [], 'status': 'SKIPPED'}, 183: {'dependencies': [], 'status': 'SKIPPED'}, 205: {'dependencies': [], 'status': 'SKIPPED'}, 184: {'dependencies': [], 'status': 'SKIPPED'}, 176: {'dependencies': [], 'status': 'SKIPPED'}, 177: {'dependencies': [], 'status': 'SKIPPED'}, 199: {'dependencies': [], 'status': 'SKIPPED'}, 178: {'dependencies': [], 'status': 'SKIPPED'}, 200: {'dependencies': [], 'status': 'SKIPPED'}, 179: {'dependencies': [], 'status': 'SKIPPED'}, 201: {'dependencies': [], 'status': 'SKIPPED'}, 180: {'dependencies': [], 'status': 'SKIPPED'}, 202: {'dependencies': [], 'status': 'SKIPPED'}, 194: {'dependencies': [], 'status': 'SKIPPED'}, 203: {'dependencies': [], 'status': 'SKIPPED'}, 195: {'dependencies': [], 'status': 'SKIPPED'}, 196: {'dependencies': [], 'status': 'SKIPPED'}, 197: {'dependencies': [], 'status': 'SKIPPED'}, 198: {'dependencies': [], 'status': 'SKIPPED'}, 190: {'dependencies': [], 'status': 'SKIPPED'}, 191: {'dependencies': [], 'status': 'SKIPPED'}, 192: {'dependencies': [], 'status': 'SKIPPED'}, 193: {'dependencies': [], 'status': 'SKIPPED'}, 185: {'dependencies': [], 'status': 'SKIPPED'}, 186: {'dependencies': [], 'status': 'SKIPPED'}, 187: {'dependencies': [], 'status': 'SKIPPED'}, 188: {'dependencies': [], 'status': 'SKIPPED'}, 189: {'dependencies': [], 'status': 'SKIPPED'}, 181: {'dependencies': [], 'status': 'SKIPPED'}, 182: {'dependencies': [], 'status': 'SKIPPED'}}, 12: {246: {'dependencies': [245], 'status': 'ACTIVE', 'num_tasks': 8192, 'num_finished_tasks': 33}, 245: {'dependencies': [242, 243, 244], 'status': 'COMPLETE', 'num_tasks': 8192, 'num_finished_tasks': 8192}, 243: {'dependencies': [], 'status': 'COMPLETE', 'num_tasks': 2, 'num_finished_tasks': 2}, 244: {'dependencies': [242], 'status': 'COMPLETE', 'num_tasks': 4096, 'num_finished_tasks': 4096}, 233: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 2, 'num_finished_tasks': 0}, 212: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 2, 'num_finished_tasks': 0}, 234: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 512, 'num_finished_tasks': 0}, 235: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 2, 'num_finished_tasks': 0}, 227: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 64, 'num_finished_tasks': 0}, 228: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 128, 'num_finished_tasks': 0}, 229: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 128, 'num_finished_tasks': 0}, 230: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 2, 'num_finished_tasks': 0}, 222: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 32, 'num_finished_tasks': 0}, 223: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 32, 'num_finished_tasks': 0}, 224: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 2, 'num_finished_tasks': 0}, 225: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 64, 'num_finished_tasks': 0}, 217: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 8, 'num_finished_tasks': 0}, 226: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 2, 'num_finished_tasks': 0}, 218: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 2, 'num_finished_tasks': 0}, 219: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 16, 'num_finished_tasks': 0}, 241: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 2048, 'num_finished_tasks': 0}, 220: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 2, 'num_finished_tasks': 0}, 242: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 4096, 'num_finished_tasks': 0}, 221: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 16, 'num_finished_tasks': 0}, 213: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 4, 'num_finished_tasks': 0}, 214: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 4, 'num_finished_tasks': 0}, 236: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 512, 'num_finished_tasks': 0}, 215: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 2, 'num_finished_tasks': 0}, 237: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 1024, 'num_finished_tasks': 0}, 216: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 8, 'num_finished_tasks': 0}, 238: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 2, 'num_finished_tasks': 0}, 239: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 1024, 'num_finished_tasks': 0}, 231: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 256, 'num_finished_tasks': 0}, 210: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 2, 'num_finished_tasks': 0}, 240: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 2048, 'num_finished_tasks': 0}, 232: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 256, 'num_finished_tasks': 0}, 211: {'dependencies': [], 'status': 'PENDING', 'num_tasks': 2, 'num_finished_tasks': 0}}, 'driver_pod': 'spark-pr-61e21a93696e2fea-driver', 13: {283: {'dependencies': [282], 'status': 'PENDING'}}}}

# %%
jobs = {'spark-pr-61e21a93696e2fea-driver': {'executors': ['sparktc-37ed2f936e753069-exec-387', 'sparktc-37ed2f936e753069-exec-465', 'sparktc-37ed2f936e753069-exec-448', 'sparktc-37ed2f936e753069-exec-500', 'sparktc-37ed2f936e753069-exec-532', 'sparktc-37ed2f936e753069-exec-519', 'sparktc-37ed2f936e753069-exec-537', 'sparktc-37ed2f936e753069-exec-277', 'sparktc-37ed2f936e753069-exec-360', 'sparktc-37ed2f936e753069-exec-236', '
source_job_input = "spark-pr-61e21a93696e2fea-driver"
num_source_exec = 0
exec_commit_input = [('sparktc-37ed2f936e753069-exec-1', 'spark-pr-a6bf569369787b21-driver'), ('sparktc-37ed2f936e753069-exec-170', 'spark-pr-a6bf569369787b21-driver')]
frontier_nodes_input = {'spark-565152936b3f47bb9e137e8fe3f60f4f': {12: [233, 212, 234, 235, 227, 228, 229, 230, 222, 223, 224, 246, 225, 217, 226, 218, 219, 241, 220, 242, 221, 213, 214, 236, 215, 237, 216, 238, 239, 231, 210, 240, 232, 211]}, 'spark-3eacdf5fcb074edf84e9e741c48bb92c': {0: [0]}, 'spark-2ed5f5179f034ccea1537a71cd150397': {0: [0]}, 'spark-692faa9eda444e6e800e5cc6f625d7c6': {0: [0]}, 'spark-116a98d1737049e7acb5d37b3239d401': {13: [263, 255, 277, 256, 278, 257, 279, 258, 250, 280, 251, 281, 273, 252, 274, 253, 275, 276, 268, 247, 269, 248, 270, 249, 271, 272, 264, 265, 266, 267, 259, 260, 282, 261, 283, 262, 254]}}
moving_executors_input = 2
MAX_EXECS = 4

# %%
from spark_env.job_dag import JobDAG
from spark_env.node import Node
from spark_env.task import Task  # Assuming you have a Task class
from spark_env.wall_time import WallTime  # Assuming you have a WallTime class
from spark_env.executor_commit import ExecutorCommit
from spark_env.moving_executors import MovingExecutors
from collections import OrderedDict
from spark_env.action_map import compute_act_map
from utils import *
from spark_env.executor import Executor

executors = [Executor(exec_id) for exec_id in range(MAX_EXECS)]

def reconstruct_job_dags(app_registry, frontier_nodes_input, exec_commit_input, moving_executors_input):
    job_dags = []
    executor_limits = {}
    moving_nodes = []
    frontier_nodes = OrderedSet()
    wall_time = WallTime()
    source_job = None
    exec_commit = ExecutorCommit()
    moving_executors = MovingExecutors()
    node_to_jobstage_map = {}
    
    # all dummy values for now
    np_random = np.random.RandomState()
    task_duration = {
        'first_wave': {1: [10, 20, 30]},  # Example values
        'rest_wave': {1: [5, 15, 25]},  # Example values
        'fresh_durations': {1: [12, 22, 32]}  # Example values
    }

    for app_id in app_registry.keys():
        for job_id in app_registry[app_id].keys():
            if job_id in ["exec_limit", "driver_pod"]:
                continue
            stages = app_registry[app_id][job_id]
            # print(stages)
            nodes = []
            adj_mat = np.zeros((len(stages), len(stages)), dtype=int)
            stage_id_to_idx = {}
            cur_idx = 0
            for stage_id in stages.keys():
                stage_id_to_idx[stage_id] = cur_idx
                cur_idx += 1
            for stage_id in stages.keys():
                stage_info = stages[stage_id]
                tasks = [Task(1, 10, 10)]  # Create a list of Task instances
                node = Node(stage_id_to_idx[stage_id], tasks, task_duration, wall_time, np_random)
                nodes.append(node)

                # map each node to an app_id, job_id, and stage_id
                node_to_jobstage_map[node] = (app_id, job_id, stage_id)

                if app_id in frontier_nodes_input.keys() and job_id in frontier_nodes_input[app_id].keys() and stage_id in frontier_nodes_input[app_id][job_id]:
                    frontier_nodes.add(node)

                if stages[stage_id]["status"] == "COMPLETE":
                    moving_nodes.append(node)

                for dep_id in stage_info["dependencies"]:
                    if dep_id not in stage_id_to_idx:
                        continue
                    adj_mat[stage_id_to_idx[dep_id], stage_id_to_idx[stage_id]] = 1
            job_dag = JobDAG(nodes, adj_mat, f"{app_id}_job_{job_id}")
            job_dags.append(job_dag)

            executor_limits[job_dag] = app_registry[app_id]["exec_limit"]

            # set the source job if the source job is in the current app_id
            if source_job_input == app_registry[app_id]["driver_pod"]:
                # if all of the stages in the current job_id are "SKIPPED" or "COMPLETE", this is the source job
                # look at the stages in app_registry[app_id][job_id]
                if all([stages[stage_id]["status"] in ["SKIPPED", "COMPLETE"] for stage_id in stages.keys()]):
                    source_job = job_dag

            # set the executor commits
            for _, job_id in exec_commit_input:
                if job_id == app_registry[app_id]["driver_pod"]:
                    exec_commit.add_job(job_dag)
            
            # set the moving executors
            for i in range(moving_executors_input):
                # choose a node from moving_nodes (randomly for now)
                node = moving_nodes[np_random.randint(len(moving_nodes))]
                moving_executors.add(executors[i], node)

    return job_dags, executor_limits, frontier_nodes, source_job, exec_commit, moving_executors, compute_act_map(job_dags), node_to_jobstage_map

# %%
job_dags, exec_limits, frontier_nodes, source_job, exec_commit, moving_executors, action_map, node_to_jobstage_map = reconstruct_job_dags(app_registry, frontier_nodes_input, exec_commit_input, moving_executors_input)
print(job_dags)
print(source_job)
print(num_source_exec)
print(frontier_nodes.to_list())
print(exec_limits)
print(exec_commit)
print(moving_executors)
print(action_map)
node = action_map[43]
print(node.idx)
print(node_to_jobstage_map[node])
# Out:
# [<spark_env.job_dag.JobDAG object at 0x30a2ab410>, <spark_env.job_dag.JobDAG object at 0x308e50950>, <spark_env.job_dag.JobDAG object at 0x30a52e010>, <spark_env.job_dag.JobDAG object at 0x174d3d990>, <spark_env.job_dag.JobDAG object at 0x30a5a4c90>, <spark_env.job_dag.JobDAG object at 0x30a5a4a10>, <spark_env.job_dag.JobDAG object at 0x174d5ea50>, <spark_env.job_dag.JobDAG object at 0x174d40850>, <spark_env.job_dag.JobDAG object at 0x174d5ef90>, <spark_env.job_dag.JobDAG object at 0x174d59710>, <spark_env.job_dag.JobDAG object at 0x174d5add0>, <spark_env.job_dag.JobDAG object at 0x174d8d510>, <spark_env.job_dag.JobDAG object at 0x30a5a4710>, <spark_env.job_dag.JobDAG object at 0x174daac50>]
# ...
# 0
# ...

# %%
print(len(job_dags))
# Out:
# 14

# %%
for i in range(len(job_dags)):
    print(len(job_dags[i].nodes))
# Out:
# 1
# 4
# 7
# 10
# 13
# 16
# 19
# 22
# 25
# 28
# 31
# 34
# 37
# 1

# %%
from actor_agent import ActorAgent

# %%
tf.compat.v1.reset_default_graph() 
tf.compat.v1.set_random_seed(42)
sess = tf.compat.v1.Session()

# %%
agent = ActorAgent(sess, 5, 3, [16, 8], 8, 8, range(1, MAX_EXECS + 1))
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/carbonDAG/lib/python3.11/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# INFO:tensorflow:Restoring parameters from ./models/stream_200_job_diff_reward_reset_5e-7_5e-8/model_ep_10000

# %%
# run inference through Decima
# get the action from the agent
obs = job_dags, source_job, num_source_exec, frontier_nodes, exec_limits, exec_commit, moving_executors, action_map, 0.0
node, use_exec, node_act_probs, job_act_probs = agent.get_action(obs)

# %%
print(node)

# %%
print(job_act_probs)
# Out:
# [[[0.25919572 0.25296652 0.24688606 0.24095178]
#   [0.2611549  0.25357327 0.24620986 0.2390621 ]
#   [0.26163825 0.253723   0.24604155 0.23859721]
#   [0.26164    0.25371987 0.24604133 0.23859882]
#   [0.2616397  0.2537215  0.24604198 0.23859674]
#   [0.         0.34361356 0.3332285  0.3231579 ]
#   [0.26162073 0.2537176  0.24604854 0.2386131 ]
#   [0.26162124 0.25371665 0.24604808 0.23861402]
#   [0.2610673  0.25354624 0.24624139 0.23914514]
#   [0.         0.343123   0.333238   0.323639  ]
#   [0.26106757 0.25354505 0.24624069 0.23914677]
#   [0.25885287 0.2528604  0.24700196 0.24128477]
#   [0.26106703 0.25354597 0.24624066 0.23914628]
#   [0.2591957  0.2529665  0.24688603 0.24095176]]]

# %%
print(node_to_jobstage_map[node])
# Out:
# ('spark-565152936b3f47bb9e137e8fe3f60f4f', 12, 220)

# %%
# use node act probs to provide weights to each job (each unique app_id and job_id pair)
job_prob = {}
stage_prob = {}

for i, prob in enumerate(node_act_probs[0]):
    node = action_map[i]
    app_id, job_id, stage_id = node_to_jobstage_map[node]
    if app_id not in job_prob.keys():
        job_prob[app_id] = {}
        stage_prob[app_id] = {}
    if job_id not in job_prob[app_id].keys():
        job_prob[app_id][job_id] = 0.0
    job_prob[app_id][job_id] += prob
    stage_prob[app_id][stage_id] = prob

print(job_prob)
print(stage_prob)
# Out:
# {'spark-565152936b3f47bb9e137e8fe3f60f4f': {0: np.float32(0.0), 1: np.float32(0.0), 2: np.float32(0.0), 3: np.float32(0.0), 4: np.float32(0.0), 5: np.float32(0.0), 6: np.float32(0.0), 7: np.float32(0.0), 8: np.float32(0.0), 9: np.float32(0.0), 10: np.float32(0.0), 11: np.float32(0.0), 12: np.float32(1.0000005), 13: np.float32(0.0)}}
# ...

# %%
pod_names = ['sparktc-37ed2f936e753069-exec-41', 'sparktc-37ed2f936e753069-exec-27', 'sparktc-37ed2f936e753069-exec-32', 'sparktc-37ed2f936e753069-exec-39', 'sparktc-37ed2f936e753069-exec-74', 'sparktc-37ed2f936e753069-exec-47', 'sparktc-37ed2f936e753069-exec-52', 'sparktc-37ed2f936e753069-exec-40', 'sparktc-37ed2f936e753069-exec-66', 'sparktc-37ed2f936e753069-exec-80', 'sparktc-37ed2f936e753069-exec-3', 'sparktc-37ed2f936e753069-exec-9', 'sparktc-37ed2f936e753069-exec-58', 'sparktc-37ed2f936e753069-exec-78', 'sparktc-37ed2f936e753069-exec-59', 'sparktc-37ed2f936e753069-exec-73', 'sparktc-37ed2f936e753069-exec-22', 'sparktc-37ed2f936e753069-exec-37', 'sparktc-37ed2f936e753069-exec-62', 'sparktc-37ed2f936e753069-exec-75', 'spark-pr-81f9ed936e74714b-driver', 'sparktc-37ed2f936e753069-
sorted_pod_names = []

# sorted_job_prob = {app_id: {k: v for k, v in sorted(job_prob[app_id].items(), key=lambda item: item[1], reverse=True)} for app_id in job_prob.keys()}

# sort the app_ids in sorted_job_prob based on the sum of the job_prob values
sorted_app_id = {k: sum(v.values()) for k, v in job_prob.items()}
sorted_app_id = {k: v for k, v in sorted(sorted_app_id.items(), key=lambda item: item[1], reverse=True)}

for app_id in sorted_app_id.keys():
    # look at pods in pod names that belong to this app_id, place them in sorted_pod_names
    driver_pod = app_registry[app_id]["driver_pod"]
    executors = jobs[driver_pod]["executors"]
    for pod_name in pod_names:
        if pod_name in executors or pod_name == driver_pod:
            sorted_pod_names.append(pod_name)

# if there are any remaining pods, add them to the end of sorted_pod_names
for pod_name in pod_names:
    if pod_name not in sorted_pod_names:
        sorted_pod_names.append(pod_name)

print(sorted_pod_names)

# prefix
# Out:
# ['sparktc-37ed2f936e753069-exec-1', 'sparktc-37ed2f936e753069-exec-41', 'sparktc-37ed2f936e753069-exec-27', 'sparktc-37ed2f936e753069-exec-32', 'sparktc-37ed2f936e753069-exec-39', 'sparktc-37ed2f936e753069-exec-74', 'sparktc-37ed2f936e753069-exec-47', 'sparktc-37ed2f936e753069-exec-52', 'sparktc-37ed2f936e753069-exec-40', 'sparktc-37ed2f936e753069-exec-66', 'sparktc-37ed2f936e753069-exec-80', 'sparktc-37ed2f936e753069-exec-3', 'sparktc-37ed2f936e753069-exec-9', 'sparktc-37ed2f936e753069-exec-58', 'sparktc-37ed2f936e753069-exec-78', 'sparktc-37ed2f936e753069-exec-59', 'sparktc-37ed2f936e753069-exec-73', 'sparktc-37ed2f936e753069-exec-22', 'sparktc-37ed2f936e753069-exec-37', 'sparktc-37ed2f936e753069-exec-62', 'sparktc-37ed2f936e753069-exec-75', 'spark-pr-81f9ed936e74714b-driver', 'sparktc-37ed2f936e753069-exec-14', 'sparktc-37ed2f936e753069-exec-44', 'sparktc-37ed2f936e753069-exec-54', 'sparktc-37ed2f936e753069-exec-30', 'sparktc-37ed2f936e753069-exec-81', 'sparktc-37ed2f936e753069-ex
# ...

# %%
print(sorted_app_id.keys())
# Out:
# dict_keys(['spark-565152936b3f47bb9e137e8fe3f60f4f'])

# %%
queue = [{'taskSet': {'tasks': [{'stageId': 67, 'stageAttemptId': 0, 'numPartitions': 2, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 67, 'stageAttemptId': 0, 'numPartitions': 2, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}], 'stageId': 67, 'stageAttemptId': 0, 'priority': 6, 'properties': {}, 'resourceProfileId': 0, 'shuffleId': 16}, 'maxTaskFailures': 4}, {'taskSet': {'tasks': [{'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}], 'stageId': 66, 'stageAttemptId': 0, 'priority': 6, 'properties': {}, 'resourceProfileId': 0, 'shuffleId': 15}, 'maxTaskFailures': 4}]

# %%
queue = []

# %%
print(queue)
# Out:
# []

# %%
# reorder the queue based on probabilities

# reorder queue based on the stage prob
sorted_stage_prob = {app_id: {k: v for k, v in sorted(stage_prob[app_id].items(), key=lambda item: item[1], reverse=True)} for app_id in stage_prob.keys()}

# do the same for stage_prob

# first extract the app id if the queue is not empty
if queue:
    app_id = queue[0]['taskSet']['tasks'][0]['appId']

    if app_id in sorted_stage_prob.keys():
        # get the probabilities for the app id
        probs = sorted_stage_prob[app_id]

        # delete stages 66, 67, and 68 to see what happens
        print(probs.keys())

        # make the order of the queue match the order in probs, based on stageId (probs.keys())
        # doing a for loop to better handle the case where probs does not contain the stages in the queue
        for stage_id in reversed(probs.keys()):
            # if the stage is in the queue, move it to the front
            for i, task in enumerate(queue):
                if task['taskSet']['tasks'][0]['stageId'] == stage_id:
                    queue.insert(0, queue.pop(i))
    print(queue)

    print(queue[0]['taskSet']['tasks'][0]['stageId'])
    print(queue[1]['taskSet']['tasks'][0]['stageId'])
# Out:
# dict_keys([246, 233, 212, 234, 235, 227, 228, 229, 230, 222, 223, 224, 225, 217, 226, 218, 219, 241, 220, 242, 221, 213, 214, 236, 215, 237, 216, 238, 239, 231, 210, 240, 232, 211, 0, 4, 3, 1, 2, 11, 10, 8, 9, 5, 6, 7, 21, 20, 18, 19, 15, 12, 16, 13, 17, 14, 34, 33, 31, 32, 30, 27, 24, 28, 25, 22, 29, 26, 23, 50, 49, 47, 48, 45, 37, 46, 38, 39, 40, 41, 35, 42, 36, 43, 44, 69, 68, 66, 67, 51, 60, 52, 53, 54, 61, 55, 62, 63, 64, 56, 57, 58, 65, 59, 91, 90, 88, 89, 81, 82, 74, 83, 75, 76, 77, 84, 78, 70, 85, 71, 86, 72, 87, 79, 73, 80, 116, 115, 113, 114, 102, 96, 103, 104, 111, 105, 97, 112, 106, 98, 92, 99, 100, 107, 101, 93, 108, 94, 109, 95, 110, 144, 143, 141, 142, 132, 133, 125, 126, 127, 128, 129, 121, 122, 123, 124, 117, 139, 118, 140, 119, 120, 134, 135, 136, 137, 138, 130, 131, 175, 174, 172, 173, 161, 153, 154, 155, 156, 148, 149, 171, 150, 151, 152, 145, 167, 146, 168, 147, 169, 170, 162, 163, 164, 165, 157, 166, 158, 159, 160, 209, 208, 206, 207, 204, 183, 205, 184, 176, 17
# ...

# %%
print(queue)

print(queue[0]['taskSet']['tasks'][0]['stageId'])
print(queue[1]['taskSet']['tasks'][0]['stageId'])
# Out:
# [{'taskSet': {'tasks': [{'stageId': 67, 'stageAttemptId': 0, 'numPartitions': 2, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}, {'stageId': 67, 'stageAttemptId': 0, 'numPartitions': 2, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': False}], 'stageId': 67, 'stageAttemptId': 0, 'priority': 6, 'properties': {}, 'resourceProfileId': 0, 'shuffleId': 16}, 'maxTaskFailures': 4}, {'taskSet': {'tasks': [{'stageId': 66, 'stageAttemptId': 0, 'numPartitions': 64, 'artifacts': {'jars': {'file:/opt/spark/examples/jars/spark-examples_2.12-3.5.3.jar': 1732726237329}, 'files': {}, 'archives': {}}, 'jobId': 6, 'appId': 'spark-565152936b3f47bb9e137e8fe3f60f4f', 'isBarrier': Fals
# ...
